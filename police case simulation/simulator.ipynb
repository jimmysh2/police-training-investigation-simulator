# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.2 MB 4.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/10.2 MB 4.9 MB/s eta 0:00:02
#    -------------- ------------------------- 3.7/10.2 MB 5.1 MB/s eta 0:00:02
#    ------------------- -------------------- 5.0/10.2 MB 5.4 MB/s eta 0:00:01
#    ------------------------- -------------- 6.6/10.2 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 8.4/10.2 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------ --- 9.2/10.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 10.2/10.2 MB 5.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 3.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
# ...

# %%
# Out:
# 2025-12-03 10:40:20.099 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-03 10:40:20.569
# ...
#   command:
#
#     streamlit run C:\pinokio\bin\miniconda\envs\jupyter\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-03 10:40:20.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-03 10:40:20.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-03 10:40:20.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-03 10:40:20.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-03 10:40:20.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
